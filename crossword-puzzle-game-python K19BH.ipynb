# %%
from tkinter import *
#Tkinter is the Python interface to the Tk GUI toolkit shipped with Python.
from tkinter import messagebox
import nltk
#The Natural Language Toolkit (NLTK) is a platform used for building Python programs 
#that apply statistical natural language processing (NLP) to human language data.
#It can be difficult to install, but is easy when you build this NLTK conda package.
from nltk.corpus import words
# This function analyze all the words that we get from the tags 
#and calculate the similarity of those words with whatwe already got
#in the dictionary and thus this function will use those results to produce an interest distribution
from time import gmtime, strftime
#Time access and conversions
import time
#import time library for one minute time limit
from collections import Counter
#Collections module implements high-performance container datatypes (beyond the built-in types list, dict and tuple) 
#and contains many useful data structures that you can use to store information in memory
nltk.download('words')
word_list = words.words()
Matrix_list=['q','a','z','w','s','x','e','d','c','r','f','v','t','g','b','y','h','n','u','j','m','i','k','l','o','p']
score=0;
window=Tk()
#using tkinter(library for GUI) function as Tk()
window.title("crossword-puzzle-game-python K19BH")
#window title bar name
window.geometry("1000x660+0+0")
#tkinter window size
def checkspells():
    global score
    #Global variables are the one that are defined and declared outside a function 
    #and we need to use them inside a function
    word=word_check.get();
    if word in word_list:
        dict = Counter(word)
        flag = 1
        for key in dict.keys():
            if key not in Matrix_list:
                flag = 0
        if flag == 1 and len(word) > 3:
            score=score+len(word)
            total="score = "+str(score)
            label.configure(text=total)
            print(word)
        else:
            messagebox.showinfo("Check","No matchine with above word OR word length should be greater than 3")
    else:
        print("No Word")
    word_check.delete(0, 'end')
def tick(time1=''):
    time2=time.strftime("%M:%S")
    if time2!=time1:
        time1=time2;
        #	timer.config(text="After 1 minute it will be closed automatically "+time2)
    #	timer.after(200,tick)
def quit_pro():
    messagebox.showinfo("Oops!!","Time Up! Your Score",+str(score))
    #when one minute (time limit) is over
    window.destroy()
    #to close the window in tkinter
def clear1():
    
    word_check.delete(0,'end')

btn1 = Button(window, text="E",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=1)
btn2 = Button(window, text="L",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20')) 
btn2.grid(column=2, row=1)
btn3 = Button(window, text="E",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=1)
btn4 = Button(window, text="P",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=1)
btn5 = Button(window, text="H",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=1)
btn6 = Button(window, text="A",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=1)
btn7 = Button(window, text="N",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=1)
btn8 = Button(window, text="T",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=1)
btn9 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=1) 
btn10 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=1)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=1)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=1)

btn1 = Button(window, text="J",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=2)
btn2 = Button(window, text="O",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=2)
btn3 = Button(window, text="J",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=2)
btn4 = Button(window, text="O",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=2) 
btn5 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=2)
btn6 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=2)
btn7 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=2)
btn8 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=2)
btn9 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=2)
btn10 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=2)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=2)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=2)

btn1 = Button(window, text="P",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=3)
btn2 = Button(window, text="Y",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=3)
btn3 = Button(window, text="T",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=3)
btn4 = Button(window, text="H",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=3)
btn5 = Button(window, text="O",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=3)
btn6 = Button(window, text="N",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=3)
btn7 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=3)
btn8 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=3)
btn9 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=3)
btn10 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=3)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=3)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=3)

btn1 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=4)
btn2 = Button(window, text="J",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=4)
btn3 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=4)
btn4 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=4)
btn5 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=4)
btn6 = Button(window, text="P",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=4)
btn7 = Button(window, text="R",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=4)
btn8 = Button(window, text="O",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=4)
btn9 = Button(window, text="J",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=4)
btn10 = Button(window, text="E",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=4)
btn11 = Button(window, text="C",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=4)
btn12 = Button(window, text="T",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=4)

btn1 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=5)
btn2 = Button(window, text="U",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=5)
btn3 = Button(window, text="N",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=5)
btn4 = Button(window, text="I",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=5)
btn5 = Button(window, text="V",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=5)
btn6 = Button(window, text="E",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=5)
btn7 = Button(window, text="R",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=5)
btn8 = Button(window, text="S",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=5)
btn9 = Button(window, text="I",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=5)
btn10 = Button(window, text="T",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=5)
btn11 = Button(window, text="Y",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=5)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=5)

btn1 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=6)
btn2 = Button(window, text="E",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=6)
btn3 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=6)
btn4 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=6)
btn5 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=6)
btn6 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=6)
btn7 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=6)
btn8 = Button(window, text="R",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=6)
btn9 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=6)
btn10 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=6)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=6)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=6)

btn1 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=7)
btn2 = Button(window, text="N",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=7)
btn3 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=7) 
btn4 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=7)
btn5 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=7)
btn6 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=7)
btn7 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=7)
btn8 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=7)
btn9 = Button(window, text="O",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=7)
btn10 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=7)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20')) 
btn11.grid(column=11, row=7)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=7)

btn1 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=8)
btn2 = Button(window, text="U",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=8)
btn3 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=8)
btn4 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=8)
btn5 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=8)
btn6 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=8) 
btn7 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=8)
btn8 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=8)
btn9 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=8)
btn10 = Button(window, text="B",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=8)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=8)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=8)

btn1 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=9) 
btn2 = Button(window, text="G",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=9)
btn3 = Button(window, text="A",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=9)
btn4 = Button(window, text="M",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=9)
btn5 = Button(window, text="E",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=9)
btn6 = Button(window, text="H",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=9)
btn7 = Button(window, text="E",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=9)
btn8 = Button(window, text="L",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=9)
btn9 = Button(window, text="L",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20')) 
btn9.grid(column=9, row=9)
btn10 = Button(window, text="O",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=9)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=9)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn12.grid(column=12, row=9)

btn1 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn1.grid(column=1, row=10)
btn2 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn2.grid(column=2, row=10)
btn3 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn3.grid(column=3, row=10)
btn4 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn4.grid(column=4, row=10) 
btn5 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn5.grid(column=5, row=10)
btn6 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn6.grid(column=6, row=10)
btn7 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn7.grid(column=7, row=10)
btn8 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn8.grid(column=8, row=10)
btn9 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn9.grid(column=9, row=10)
btn10 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn10.grid(column=10, row=10)
btn11 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20'))
btn11.grid(column=11, row=10)
btn12 = Button(window, text="",bg="White", fg="Black",width=2,height=1,font=('Helvetica','20')) 
btn12.grid(column=12, row=10)

word_check=Entry(window,width=20, bd=0)
#widget entry to give input
word_check.configure(highlightbackground="red", highlightcolor="red",bg="yellow")
word_check.place(x=82,y=580)
word_check.focus()
btncheck = Button(window, text="Submit",bg="blue", fg="white",width=5,font=('Helvetica','10'),command=checkspells)
btncheck.place(x = 82, y = 600)
btncheck = Button(window, text="reset",bg="blue", fg="white",width=5,font=('Helvetica','10'),command=clear1)
btncheck.place(x = 200, y = 600)
label=Label(window,text=" Score = 0",bg="blue", fg="white",width=8,font=('Helvetica','50'))
label.place(x=600, y=200)
timer=Label(window,text="You have 1 minute")
timer.place(x=300, y=600)
tick()
window.after(60000, quit_pro)
window.mainloop()
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\satis\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# No Word
# hello
# hello
# game
# game
